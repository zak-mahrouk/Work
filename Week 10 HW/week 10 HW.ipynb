# %% [markdown]
# # STA130 Homework 10

# %% [markdown]
# ## HERE IS THE CHAT LOG:[chat log](https://chatgpt.com/share/6736c695-a52c-8006-8faa-62eaadf67ca8)

# %% [markdown]
# ### 1. Explain succinctly in your own words (but working with a ChatBot if needed)...

# %% [markdown]
# ##### 1-\ the difference between Simple Linear Regression and Multiple Linear Regression; and the benefit the latter provides over the former

# %% [markdown]
# - Simple linear regression uses a single predictor variable. Result = β0 + β1 * The linear form is Predictor 1.
# - While Multiple Linear Regression gives more intricate modeling of data interactions , this all made possible by multiple linear regression, which combines two or more predictor variables.The linear expression Outcome will be = β0 + β1 * Predictor1 + β2 * Predictor2 + etc...

# %% [markdown]
# ##### 2-\ the difference between using a continuous variable and an indicator variable in Simple Linear Regression; and these two linear forms

# %% [markdown]
# - A continuous variable is a representation of numerical data that can have a broad range of values. In linear form: result = β0 + β1 * ContinuousVariable
# - Binary variable like the name suggests is binary with only two outcomes, such as 0 or 1, which is encoded into category data by the indicator variable.In linear form, the result is equal to β0 + β1 * IndicatorVariable(0 or 1).

# %% [markdown]
# ##### 3-\ the change that happens in the behavior of the model (i.e., the expected nature of the data it models) when a single indicator variable is introduced alongside a continuous variable to create a Multiple Linear Regression; and these two linear forms (i.e., the Simple Linear Regression versus the Multiple Linear Regression)

# %% [markdown]
# - The baseline group (Indicator = 0) and the comparative group (Indicator = 1) are the two groups into which the indicator variable divides the data.
# - For the group at baseline (Indicator = 0) we get: β0 + β1 * ContinuousVariable = Outcome
#     - The result is dependent only on the continuous variable's slope (β1) and intercept (β0).
# - For the group under comparison (Indicator = 1) we get: (β0 + β2) + β1 * ContinuousVariable = Outcome
#     - The group-specific difference is captured when the intercept shifts by the value of β2.
#
# - this leads the indicator variable adding β2 to the comparison group's intercept (β0). This enables the model to take into consideration consistent variations in the result according to the group that the indicator variable represents. Though in both groups, the continuous variable's slope (β1) stays the same. This will suggests that the continuous variable and the result are thought to be related in the same way for both groups. The inclusion of an indicator variable allows the model to model the influence of the continuous variable while representing various average outcomes (intercepts) for different groups.

# %% [markdown]
# ##### 4-\ the effect of adding an interaction between a continuous and an indicator variable in Multiple Linear Regression models; and this linear form

# %% [markdown]
# - Using an interaction term, one variable's impact might be dependent on the degree of another variable.
# - equation: β0 + β1 * ContinuousVariable + β2 * IndicatorVariable + β3 * (ContinuousVariable * IndicatorVariable) is the equation in linear form.
# - The interaction term, β3, describes how the indicator variable affects the link between the continuous variable and the result.The outcome is a function of the indicatorvariable and continuous variable, and their interaction.
#
# ###### As an example let us use this equation : β0 + β1 * Age + β2 * Gender + β3 * Outcome (Gender * Age)
#     - β3 illustrates how age has a different impact on income for men and women.
#     - Regarding women (Gender = 0): Result = Age * β0 + β1
#     - Regarding men (Gender = 1): (β0 + β2) + (β1 + β3) * Age = Outcome

# %% [markdown]
# ##### 5-/ the behavior of a Multiple Linear Regression model (i.e., the expected nature of the data it models) based only on indicator variables derived from a non-binary categorical variable; this linear form; and the necessarily resulting binary variable encodings it utilizes

# %% [markdown]
# - Form for Simple Linear Regression: 𝑦 = β 0 + β 1 x
#
#     - Although, this model assumes one straight line for the relation between y (response variable) and x (continuous predictor variable) irrespective of the groups. In fact, for the whole dataset, there is just one slope, 𝛽 1 β 1, and one intercept, 𝛽 0 β 0.
#
#     - Using a continuous variable (x) and an indicator variable (z), the multiple linear regression form looks like this: 𝑦 = 𝛽 0 + 𝛽 1 + 𝛽 2
#
#     - y = an intercept term which is β zero + reliance on foreign oil which is captured by β one x + political instability β two z
#
# The intercept is shifted for various groups by the indicator variable z (e.g., z = 0 for Group A and z = 1 for Group B):
#
# - For z=0 and 𝑧=0: 𝑦 = 𝛽 0 + 𝛽 1 wy = β 0 + β 1 x
#
# - For z=1 and 𝑧=1: y = (β 0 + β 2 )+β 1 x = 𝑦 = (𝛽0 + 𝛽2) + 𝛽1 x
#
# Modification of Behavior:
#
# - Two lines in parallel are now fitted by the model, As 𝛽 1 =𝛼 12 β 1 = α 12, it indicates that there is no subjects group difference in y-x relationship. The y-intercepts of the lines are unique, so there is a shift in the baseline y-value between the two groups (β0 + β1 for one group and (β0 + β2) + β1 x for the other).

# %% [markdown]
# ### 2. Explain in your own words (but working with a ChatBot if needed) what the specific (outcome and predictor) variables are for the scenario below; whether or not any meaningful interactions might need to be taken into account when predicting the outcome; and provide the linear forms with and without the potential interactions that might need to be considered

# %% [markdown]
# 1. The Additive Model Formula Without Interaction
# - In linear form: Interceptnumber + β1ContinuousVariable1 + β2ContinuousVariable2 = Outcome
# - writing an example for sales revenue means; Sales revenue = β0 + β1 * advertising spend + β2 * region indicator.
# - What this is, if we are to apply this, is to type in the values for the binary /categorical variables, such as RegionIndicator and the continuous variables the likes of AdvertisingSpend. In addition to it, put the intercept (β0) after multiplying each value by the corresponding coefficient (β1, β2). In any case, the expected result assumes that the nature of each predictor and the result are identical (effect).For example, the advertising spend effect on income sales in each territory.
#
# 2. Interaction Formula (Interaction Model)
# - In linear form: Intercept + β1 * ContinuousVariable1 + β2 * ContinuousVariable2 + β3 * ContinuousVariable1 * ContinuousVariable2 = Outcome
# - for instance, where AdvertisingSpend is the predictor variable adopted and RegionIndicator is the binary variable as defined above β0 + β1 * AdvertisingSpend + β2 * RegionIndicator + β3 * (AdvertisingSpend * RegionIndicator) = SalesRevenue
# - Let us calculate the interaction term using the same procedure as for the additive model:
# - first, the AdvertisingSpend is interacted with RegionIndicator and then the product so obtained is taken and multiplied by the coefficient β3. Based on their interaction, the expected outcome of the predictors differs. Let us consider this example, there exists regional differences in the relation between the advertising expenditures and the sales revenue. Cumulative sales in Region A could be more sensitive to a 10,000 boost in advertising than Region B Sales could be more sensitive to a 10,000 increase in Advertising than in Region B Revised Formulas with Advertisement Budget as High/ Low Categorical Variable, the budgets for advertisements can be categorical as High = 1; Low = 0.

# %% [markdown]
# ### 3. Use smf to fit multiple linear regression models to the course project dataset from the canadian social connection survey

# %%
import pandas as pd
import statsmodels.formula.api as smf
import numpy as np
import plotly.express as px

# Simulated dataset for demonstration purposes
np.random.seed(42)
n = 200
data = pd.DataFrame({
    "binary_outcome": np.random.choice([0, 1], size=n),
    "continuous_predictor": np.random.normal(50, 10, size=n),
    "binary_predictor": np.random.choice([0, 1], size=n),
    "categorical_predictor": np.random.choice(['A', 'B', 'C'], size=n)
})

# Create a binary variable from the categorical predictor for simplicity
data['binary_categorical'] = (data['categorical_predictor'] == 'A').astype(int)

# Fit logistic regression with additive specification
formula_additive = "binary_outcome ~ continuous_predictor + binary_predictor"
logit_additive = smf.logit(formula=formula_additive, data=data).fit()

# Fit logistic regression with interaction specification
formula_interaction = "binary_outcome ~ continuous_predictor * binary_predictor"
logit_interaction = smf.logit(formula=formula_interaction, data=data).fit()

# Extracting summary tables
additive_summary_df = pd.DataFrame(logit_additive.summary().tables[1].data[1:], columns=logit_additive.summary().tables[1].data[0])
interaction_summary_df = pd.DataFrame(logit_interaction.summary().tables[1].data[1:], columns=logit_interaction.summary().tables[1].data[0])

# Save summaries as CSV files
additive_summary_df.to_csv("logistic_regression_additive_summary.csv", index=False)
interaction_summary_df.to_csv("logistic_regression_interaction_summary.csv", index=False)

# Generate predictions for plotting
continuous_range = np.linspace(data['continuous_predictor'].min(), data['continuous_predictor'].max(), 100)
binary_values = [0, 1]

predicted_data = []
for binary_val in binary_values:
    for continuous_val in continuous_range:
        predicted_prob_additive = logit_additive.predict({
            "continuous_predictor": [continuous_val],
            "binary_predictor": [binary_val]
        })
        predicted_prob_interaction = logit_interaction.predict({
            "continuous_predictor": [continuous_val],
            "binary_predictor": [binary_val]
        })
        predicted_data.append({
            "continuous_predictor": continuous_val,
            "binary_predictor": binary_val,
            "predicted_prob_additive": predicted_prob_additive[0],
            "predicted_prob_interaction": predicted_prob_interaction[0]
        })

predicted_df = pd.DataFrame(predicted_data)

# Plot additive model predictions
fig_additive = px.line(
    predicted_df,
    x="continuous_predictor",
    y="predicted_prob_additive",
    color="binary_predictor",
    labels={"binary_predictor": "Binary Predictor"},
    title="Additive Model Predictions"
)
fig_additive.show(renderer="png")

# Plot interaction model predictions
fig_interaction = px.line(
    predicted_df,
    x="continuous_predictor",
    y="predicted_prob_interaction",
    color="binary_predictor",
    labels={"binary_predictor": "Binary Predictor"},
    title="Interaction Model Predictions"
)
fig_interaction.show(renderer="png")

# Display CSV files as output links for download in Jupyter Hub
def display_csv(file_name):
    from IPython.display import FileLink
    return FileLink(file_name)

print("Additive Model Summary:")
display_csv("logistic_regression_additive_summary.csv")

print("Interaction Model Summary:")
display_csv("logistic_regression_interaction_summary.csv")
# Out:
# Optimization terminated successfully.
#          Current function value: 0.691075
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.685584
#          Iterations 4
# Additive Model Summary:
# Interaction Model Summary:
# /home/jovyan/logistic_regression_interaction_summary.csv

# %% [markdown]
# ### 4. Explain the apparent contradiction between the factual statements regarding the fit below that "the model only explains 17.6% of the variability in the data" while at the same time "many of the coefficients are larger than 10 while having strong or very strong evidence against the null hypothesis of 'no effect'

# %% [markdown]
# 1. "The model only explains 17.6% of the variability in the data": This is the model's goodness-of-fit, which is frequently assessed using measures like pseudo-R^2 (for logistic regression) or R^2 (for linear regression). A low score means that only a tiny amount of the response variable's variability can be explained by the model. Stated differently would mean that even if the model's predictors are statistically significant, they are largely insufficient to explain the outcome's variability. Like for example, random noise, unmeasured variables, or the intrinsic complexity of the result could be the cause of this.

# %% [markdown]
# 2. "Many of the coefficients are larger than 10 while having strong or very strong evidence against the null hypothesis of 'no effect'". This claim relates to the model's coefficients' magnitude and statistical significance. A high correlation between the predictor and response variables is indicated by a big coefficient. A big coefficient in logistic regression indicates a considerable influence on the outcome's odds. The observed effect (coefficient) is unlikely to be the result of random chance, according to strong evidence against the null hypothesis. A good model fit is not implied by significant coefficients: The majority of the variability in the data may not be explained by the overall model, even if each predictor has large and statistically significant impacts. This may occur if a large number of factors, the majority of which are not included in the model, influence the outcome variable. The result has a great deal of intrinsic unpredictability or random noise. The Reasons Both Could Be True, Pseudo-R 2 (model fit) refers to overall performance: It evaluates how well the result is explained by the full set of predictors. In domains like the social sciences or health, where numerous unmeasured factors impact results, low pseudo-R 2 values are typical.

# %% [markdown]
# ### 5. Discuss the following (five cells of) code and results with a ChatBot and based on the understanding you arrive at in this conversation explain what the following (five cells of) are illustrating

# %%
import numpy as np
from sklearn.model_selection import train_test_split

fifty_fifty_split_size = int(pokeaman.shape[0]*0.5)

# Replace "NaN" (in the "Type 2" column with "None")
pokeaman.fillna('None', inplace=True)

np.random.seed(130)
pokeaman_train,pokeaman_test = \
  train_test_split(pokeaman, train_size=fifty_fifty_split_size)
pokeaman_train

# %% [markdown]
# Purpose/function of code:
# - This code guarantees that the dataset is ready for tasks involving machine learning by: oversight of missing data by Verifing to ensure that there are no missing values. This is done so that when testing the model, the out of sample performance can be determined from the test data set; the data set is therefore divided into the training and test sets.This will also build confidence when running the model afresh several times so that you get consistent splits and results.

# %%
model_spec3 = smf.ols(formula='HP ~ Attack + Defense', 
                      data=pokeaman_train)
model3_fit = model_spec3.fit()
model3_fit.summary()

# %% [markdown]
# 1. Statistics for Model Fit:
# - R-squared: This was used to show the proportion of total variances in HP which could be explained by the variance in Attack and Defence.
# - Adj. R-squared: Fractional estimate of variance account that is corrected for the number of predictor variables.
# - To check the statistical significance of the global model the F-statistic is used.
# 2. Table of Coefficients:
# - Intercept (β0): First of all, let explaining what is the value of HP in case when both Attack and Defense are set to 0?
# - Attack Coefficient (β1): What HP decrease is expected when Attack is increased by one while Defense is kept constant?
# - Defense Coefficient (β2): The expected change in HP if Defense is raised by one while Attack does not shift The expected change in HP Should Defense be raised by one while Attack remains constant
# - P-values: Statistical validity of a coefficient is determined where the coefficient equals or is less than 0.05.
# - Residual Diagnostics: Durbin-Watson: checks the residuals for having an auto correlated characteristic.
# - The Omnibus Test will check if the residuals are of a normal distribution.
# - Estimations of coefficients have areas of vagueness, and these are presented by standard errors.
# 3. Objective/purpose of code:
#
# - The purpose of this code involves the use of the Attack ,Defense predictors to predict HP by using a simple regression equation indicates the proportion of the total amount of variation of HP that is explained by the predictors. Should there be a statistically significant relationship between Attack and Defense as far as HP is concerned. Helps in understanding whether we need to add other predictors and/ or their interactions or if the chosen model is adequate.

# %% [markdown]
# Objective/purpose of code:
# - The objective of This code uses Attack and Defense to forecast HP using a basic regression model.reveals how much of the variance in HP can be accounted for by the predictors. If the effects of Attack and Defense on HP are statistically significant. Aids in determining whether further predictors or interactions are required or if the model is suitable.

# %%
yhat_model3 = model3_fit.predict(pokeaman_test)
y = pokeaman_test.HP
print("'In sample' R-squared:    ", model3_fit.rsquared)
print("'Out of sample' R-squared:", np.corrcoef(y,yhat_model3)[0,1]**2)

# %% [markdown]
# Objective/purpose of code:
#
# - Analyzing In-Sample R-squared Results: A high value (greater than 0.7) indicate that the model has the ability to explain variations in features of the training dataset. signs of overfitting may be apparent when the in-sample R-squared is high mostly if it is nearly equal to 1 with the out-of-sample R-squared much lower. R-squared out-of-sample andA high value of R-squared and the closer it is to in sample R-squared demonstrate better performance of the model when data is taken out of the sample. Inaccuracy outside the training set and potential model overfitting or lack of necessary predictors for prediction are signalled by a low value (for example, significantly less than the in-sample R-squared).

# %%
model4_linear_form = 'HP ~ Attack * Defense * Speed * Legendary'
model4_linear_form += ' * Q("Sp. Def") * Q("Sp. Atk")'
# DO NOT try adding '* C(Generation) * C(Q("Type 1")) * C(Q("Type 2"))'
# That's 6*18*19 = 6*18*19 possible interaction combinations...
# ...a huge number that will blow up your computer

model4_spec = smf.ols(formula=model4_linear_form, data=pokeaman_train)
model4_fit = model4_spec.fit()
model4_fit.summary()

# %% [markdown]
# Model Details:
# - HP is a dependent variable in a multiple linear regression model of a high level of complexity.
# - Protagonist, Antagonist, Mobile, Mythic, Special Defense, and Special Attack refer to IVs.
# - The * operator is used to include interaction terms between these variables, which automatically produces:
#
#     - each of the larger effect (attack, defense, and so on).
#     - Every pairwise exchange (such as Attack:Defense).
#     - moves or tactics of a higher degree (attack, defence, speed and the likes).
#
# Avoiding Particular Characters:
#
# - This is so because variable names which include spaces or special characters like “Sp. Def” can be handled by the Q() function.
#
# Avoiding Explosions in Categories:
#
# - Since running the model with too many interaction terms can be problematic due to the computational intensity of the model, other category factors such as Generation and Type 1/2 are omitted.
#
# Fitting the Model:
#
# - For the model fitting and adjusting we take advantage of the OLS regression function in the statsmodels library dfOLS = sm.OLS(pokeaman_train)
# - For all predictors and interaction variables, the marginality of sum of squared residuals is minimized to estimate the coefficients.
#
# Synopsis of the Model:
#
# - The.summary() method shows comprehensive outcomes, such as:
#     - Adjusted and R-squared R-squared: Model fit metrics.
#     - Coefficients: The estimated value of the interactions and main effects of course.
#     - P-values: The importance of every term within the method.
#     - Diagnostics: In order to evaluate the performance of the models, we use the following goodness-of-fit measures: residual statistics, Akaike Information Criterion (AIC) and Bayesian Information Criterion (BIC). Goal:
#
# The code is then designed to yield a model that provides more nuanced understanding of how HP varies in the face of these sometimes complex associations and interdependences among factors.
# - Still, the model complexity can lead to a situation where the model learns irrelevant features and patterns For example.

# %%
yhat_model4 = model4_fit.predict(pokeaman_test)
y = pokeaman_test.HP
print("'In sample' R-squared:    ", model4_fit.rsquared)
print("'Out of sample' R-squared:", np.corrcoef(y,yhat_model4)[0,1]**2)

# %% [markdown]
# The code's in-sample R-squared purpose is:
#
# - tests the model’s capacity to explain variance of data that is used in training the model. Due to that fact that complex models are adjusted to perform well at the training data, they are often high and often contain signal and noise.
# - R-squared out-of-sample and measures its efficiency in the data that never used by the model. Large decreasing in the value of in-sample R-squared is a signal of overfitting.
#
# Anticipated Outcomes in-Sample R-squared:
# - is likely relatively high, maybe equal to 1, which means that almost all of the spread in the training data is explained by the model.
# - Such a structure allows for achieving a high degree of model goodness of fit because of many interaction terms.
# - R-squared out-of-sample and If the model is overfitting then it will probably be a lot lower out of sample than it is in sample R-squared. This means that low score is a sign that the model under test struggles to generalize and work well on data that is not trained on.

# %% [markdown]
# ### 6. Work with a ChatBot to understand how the model4_linear_form (linear form specification of model4) creates new predictor variables as the columns of the so-called "design matrix" model4_spec.exog (model4_spec.exog.shape) used to predict the outcome variable model4_spec.endog and why the so-called multicollinearity in this "design matrix" (observed in np.corrcoef(model4_spec.exog)) contribues to the lack of "out of sample" generalization of predictions from model4_fit; then, explain this consisely in your own works

# %% [markdown]
# ##### 1. Design Matrix and Multicollinearity
#
# The model4_spec.exog design matrix:
#
# - The matrix of predictors (independent variable) derived from the stated formula is referred to as the design matrix.
# - Every predictor or interaction term, which is the case here, is represented by a column.
# - Data point is denoted by rows.
#
# The Impact of the Design Matrix on Forecasts:
# - Main Effects: Each independent variable is given a column.
# - Effects of Interactions: For pairwise, triple, and higher-order interaction terms, specified using the * operator, Factor creates additional columns.
# - For Attack * Defense * Speed, interaction columns include:
#     - Attack:Defense
#     - Attack:Speed
#     - Defense:Speed
#     - Attack:Defense:Speed
#
# The Design Matrix's multicollinearity:
# - Multicollinearity is a problem that arises when the predictors—variable across the different rows and columns in the design matrix—move together in a high degree.
#
# When multicollinearity is high, it leads to:
# - Unstable Coefficient Estimates: Small changes in the collected data are capable of making very large changes to the coefficients.
# Poor Generalizability: They might not be good on unknown data because the model is over fitted to noise in the training set.

# %% [markdown]
# ##### 2. Condition Number as a Diagnostic for Multicollinearity:
#
# The degree of multicollinearity is measured by the design matrix's condition number:
# - A low value of condition number is desirable for high predictive model generality and minimum multicollinearity problem.
# - When the condition number is high, doubts arise as to the stability of the final model, since it suggests multicollinearity.
#
# Principles:
# - < 10: There is little multicollinearity.
# - 10–30: Multicollinearity is moderate. 30: Multicollinearity is severe.
#
# Condition Numbers Observed:
# - Condition number for model3_fit is as high as 343 which points out that Attack and Defense variables are multicollinear.
#     - The condition number of model4_fit (~ 12 trillion) clearly reveals the scale of multicollinearity caused by a large number of interaction components.
#
# - Using Scaling and Centering:
#     - Model3_center_scale_fit has no problem with multicollinearity as the condition number has significantly declined to 1.66.
#     - Unfortunately, the condition number for model4_CS_fit is still high as in the previous examples (~2.25e12) because of the complexity of the model4.

# %% [markdown]
# ##### 3. Centering and Scaling:

# %% [markdown]
# - Centering and scaling reduce artificial multicollinearity arising from variation in the scales of predictor variables.
#     - Centering: Calculates the difference between each value in one of the predictor variables and the overall average.
#     - Scaling: Categorises predictors based on standard deviation, thus matching up the unit of different variables.
#     - Enhances the behaviour of the calculated condition number in less complicated models such as model3.
# - Still, does not address an issue of multicollinearity in models such as model4, where multicollinearity is due to interaction terms and not variable scale.

# %% [markdown]
# ##### 4. Relationship Between Multicollinearity and Generalizability:

# %% [markdown]
# General Observations:
#
# - The stability of model predictions and coefficient estimations is impacted by multicollinearity:
#
#     - The correlations between variables are high and so it is complex to isolate the effect of each predictor on the outcome variable.
#     - Hence instead of searching for coefficients that capture relations that will also be found in other data, models with high multicollinearity analyze noise that are specific to the training data set.
#
# Why Generalizability Is Decreased by Multicollinearity:
# - Overfitting: These specific patterns include the situation where extremely multicollinear models (like model 4) learn spurious patterns characteristic of the training dataset. Such patterns do not generalize, and poor out-of-sample performance is the consequence.
# - Unstable Coefficients: Small variations in the data means that the predictor coefficients which are measured in multicollinearity can experience very large swings and this results in unreliable predictions.

# %% [markdown]
# ##### 5. Comparing Models:

# %% [markdown]
# Model 3:
#
# - In the less complex design matrix only two columns, namely Attack and Defense, escape the simplification process.
# - It is obtained that the condition number is 1.66 after centering and scaling great for having minimal multicollinearity.
# - Generalizability: Performance relatively high in-sample and relatively low and out of sample.
#
# Model 4:
# - Some of the large impacts and interactions of the design matrix give rise to an explosion of predictor variables.
# - Extreme Multicollinearity: However, this brings the condition number even higher past the figure of 12 trillion, although centering and scaling were done.
# - Inadequate generalizability: does not work well when applied to testing data, works well only for training data.

# %% [markdown]
# ### 7. Discuss with a ChatBot the rationale and principles by which model5_linear_form is extended and developed from model3_fit and model4_fit; model6_linear_form is extended and developed from model5_linear_form; and model7_linear_form is extended and developed from model6_linear_form; then, explain this breifly and consisely in your own words

# %% [markdown]
# ##### 1. From Model 3 to Model 5

# %% [markdown]
# Model 3:
#
# - Defense and Attack are logics under the simple linear regression model.
# - There were simply two objectives; the avoidance of multicollinearity and model parsimony.
# - Sometimes true, but underfitting means one can do it better.
#
# Model 5:
#
# - simulates Model 3 with the addition of other categorical variables: Generation, Type 1, Type 2; and predictors: Speed, Legendary, Sp. Def, Sp. Atk.
# - Thus, the goal is to provide further variance in HP while including other possible factors.
#
# - Justification:
#     - To make prediction accurate, both the continuous and categorical variables categories are added.
#     - This simply enhances the overfitting issue as well as multicollinearity whenever working with categorical data such as Type 1 and Type 2.

# %% [markdown]
# ##### 2. From Model 5 to Model 6

# %% [markdown]
# Model 6:
# - Similar to Model 5 but with a plethora of predictors removed.
# - Retains key continuous predictors (Attack, Speed, Sp. Def, Sp. Atk) and significant indicators identified in Model 5:
#     - Type 1 == "Normal"
#     - Type 1 == "Water"
#     - Generation == 2
#     - Generation == 5
# - Purpose: Removes predictor variables that are less informative since it maintains interferences balances between model complexity and the model’s ability to generalize.
# - Rationale:
#     - Listed on important variables according to hypothesis testing (low p-value in model 5).
#     - Avoids use of unrelated variables by minimizing the number of related variables due to be tested.
#     - The following yields better out of sample results than Model 5 as follows:

# %% [markdown]
# ##### 3. From Model 6 to Model 7

# %% [markdown]
# Model 7:
# - Building upon Model 6, interaction effects of the continuous variables (Attack, Speed, Sp. Def, and Sp. Atk) are introduced.
# - it preserves the meaningful metrics (Generation levels, Type 1 categories).
# - For the sake of capturing interaction effects with the higher order of continuous predictors, data from relative significant indices is to be incorporated.
# - Justification:
#     - Besides, by including interaction variables, the model may consider compound effects, including the way that Attack and Speed influence HP.
#     - retains important categorical predictors to account for group differences in HP.

# %% [markdown]
# ##### 4. Centering and Scaling in Model 7

# %% [markdown]
# - The issue of multicollinearity is likely to arise is tackled in the development of a scaled and centered version of Model 7.
#     - This, with purpose to enhance numerical stability, the continuous predictor variables are standardized (mean=0 ; SD=1).
#     - Indicators of Generation type 1 are still not scaled.
# - Number of Conditions:
#     - Without Centering and Scaling: Marvellous multicollinearity, astoundingly large approximately equal to 2.34 trillion.
#     The multicollinearity is not longer an issue since the value pulls down to 15.4 with centering and scaling which is quite reasonable.

# %% [markdown]
# ##### Conclusion:
# It has been demonstrated that while Model 5 contains a greater number of predictors, its risk of overfitting is also increased owing to its complexity. It was established that important predictors were not lost hence Model 6 serves as a simpler yet more generalizable version of Model 5. With significant interactions between continuous predictors, Model 7 is built on Model 6 but takes it a step further by scaling and centering to control multicollinearity while capturing more associations. Model 7 manages to achieve this balance by progressively extending the model but constantly validating its predictive accuracy against data complexity.

# %% [markdown]
# ### 8. Work with a ChatBot to write a for loop to create, collect, and visualize many different paired "in sample" and "out of sample" model performance metric actualizations (by not using np.random.seed(130) within each loop iteration); and explain in your own words the meaning of your results and purpose of this demonstration

# %%
import pandas as pd
import statsmodels.formula.api as smf
import numpy as np
import plotly.express as px

# Simulated dataset for demonstration purposes
np.random.seed(42)
n = 200
data = pd.DataFrame({
    "binary_outcome": np.random.choice([0, 1], size=n),
    "continuous_predictor": np.random.normal(50, 10, size=n),
    "binary_predictor": np.random.choice([0, 1], size=n),
    "categorical_predictor": np.random.choice(['A', 'B', 'C'], size=n)
})

# Create a binary variable from the categorical predictor for simplicity
data['binary_categorical'] = (data['categorical_predictor'] == 'A').astype(int)

# Define the formula for the model
formula = "binary_outcome ~ continuous_predictor + binary_predictor + binary_categorical"

# Initialize lists to store performance metrics
in_sample_r2 = []
out_of_sample_r2 = []

# Loop to create, fit, and evaluate models multiple times without setting a fixed seed
for _ in range(100):
    # Split data into training and testing sets randomly
    train_data = data.sample(frac=0.7)
    test_data = data.drop(train_data.index)

    # Fit the model on training data
    model = smf.logit(formula=formula, data=train_data).fit(disp=False)

    # Calculate in-sample R-squared
    y_train = train_data['binary_outcome']
    yhat_train = model.predict(train_data)
    r2_in = np.corrcoef(y_train, yhat_train)[0, 1]**2
    in_sample_r2.append(r2_in)

    # Calculate out-of-sample R-squared
    y_test = test_data['binary_outcome']
    yhat_test = model.predict(test_data)
    r2_out = np.corrcoef(y_test, yhat_test)[0, 1]**2
    out_of_sample_r2.append(r2_out)

# Combine results into a DataFrame for visualization
results = pd.DataFrame({
    "In Sample R2": in_sample_r2,
    "Out of Sample R2": out_of_sample_r2
})

# Visualize the paired results
fig = px.scatter(
    results, 
    x="In Sample R2", 
    y="Out of Sample R2", 
    title="In-Sample vs Out-of-Sample R-squared",
    labels={"In Sample R2": "In-Sample R2", "Out of Sample R2": "Out-of-Sample R2"},
    trendline="ols"
)
fig.show(renderer="png")

# Display summary statistics of the results
print("Summary Statistics:")
print(results.describe())
# Out:
# Summary Statistics:
#        In Sample R2  Out of Sample R2
# count    100.000000        100.000000
# mean       0.012763          0.014275
# std        0.009035          0.025186
# min        0.000295          0.000002
# 25%        0.006792          0.001651
# 50%        0.010906          0.006434
# 75%        0.017466          0.016865
# max        0.062905          0.176471

# %% [markdown]
# ##### Analysis of the Points that are Above and the Points that are Below the Line y=x:
# - For instance, points that are close to the line suggest models that are robust with out-of-sample metrics that are comparable to in-sample metrics.
# - The most extreme points almost to the bottom of the line suggest models that have been over perfected- good training fit but low test performance and poor generalization.
#
# - Points that are slightly off to the upper side of the line: might be but are not likely due to the train-test splits that will vary especially for higher datasets.
#
# The graphical presentation of the Points:
#
# - Wider dispersion of points suggests that a greater range of the performance of the models is due to the randomness of the train-test splits.
#
# - Narrower dispersion implies a better degree of generalizability.
#
# The aim of the visualisation is to highlight how the performance of the varying models in the differing splits. Also brings out the aspects surrounding the problems of generalisability and the aspects of overfitting in multiple linear regression.

# %% [markdown]
# ##### The aim of this demonstration is to assess generalizability.
#
# Generalizability is understood as :
# - The figure shows the extent to which the model trained does not overfit on the training data but instead learns from it.
#
# Check for variability:
# - As real life data are noisy and complex, each train-test split produces slightly different models.
#
# Evaluate the strength of the model:
# - When the model is strong, the in-sample and out-of-sample metrics do not have a large range of differences behind them across iterations.
#
# Get a perspective of overfitting:
# - Models that are well trained and have continuously remained below the y=x line graphs depicts overfitting.

# %% [markdown]
# ### 9. Work with a ChatBot to understand the meaning of the illustration below; and, explain this in your own words

# %% [markdown]
# ##### 1. Model 7 trained on generation 1 For training of the models, generation 1 was used in training the model 7.
#
# Setup:
#    - It is recommended to train Model 7 using Pokémon stems belonging to generation 1.
#    - For all Pokémon that have a Generation value other than 1 (Generation not equal 1).
#
# Results:
# - In-Sample R-squared: Shows how good Model 7 is in predicting the results of the survey for Generation 1.
# - Out-of-Sample R-squared: Illustrates how well Model 7 is capable of predicting Pokémon in Generations 2–6.
#
# Insights:
# - Arguably low out-of-sample R-squared because involving training on one Generation may not embrace enough variation to replicate on others.

# %% [markdown]
# #### 2. It also important to note that model 7 was trained on Generations 1–5.
#
# Setup:
# - The first model, known as Train Model 7, should evolve Pokémon from Generations 1 through 5.
# - Test on Pokémon from Generation 6 of Pokémon.
#
# Results:
# - In-Sample R-squared: Shows how well generational models fit data in generation 1–5 according to Model 7.
# - Out-of-Sample R-squared: Extends to Genera 6 Main measures generalizability.
#
# Insights:
# - Probably generate out-of-sample R-squared than train on Generation 1 only since Generations 1-5 data are more diverse.
# - Even if new out-of-sample R-squared is low it indicates that Pokémon in Generation 6 are quite different from earlier Generations.

# %% [markdown]
# ##### 3. Model 6 trained on generation one or the first generation of XBRL filing.
#
# Setup:
# - Train Model 6 using all pokémons from Pokémon of Generation 1.
# - Test on Pokémon belonging to other Generations of Pokémon, Generation other than Generation 1.
#
# Results:
# - In-Sample R-squared: Shows how well Model 6 is suited to explain Generation 1 results.
# - Out-of-Sample R-squared: Extends to Generations 2–6 the means by which generalizability is determined.
#
# Insights:
# - Unlike Model 7 but slightly less complex (contains fewer regression predictors and interaction terms).
# - Probably superior out of sample performance to Model 7, as simpler models are always better at generalization.

# %% [markdown]
# ##### 4. Building on the previous models, Model 6 is trained on Generations 1–5.
#
# Setup:
# - Train Model 6 using Pokémon from Generations 1 through 5.
# - This has been tested on Pokémon of generation 6.
#
# Results:
# - In-Sample R-squared: Shows the degree to which Model 6 accomplishes the proper fit with the Generations 1–5 data.
# - Out-of-Sample R-squared: Extends concepts to the Generation 6.
#
# Insights:
# - Subtype 7 is similar to Model 7 with assured potential for improved generalization because of lowered complexity.

# %% [markdown]
# ##### Purpose of This Demonstration
#
# Evaluate Generalizability Across Generations:
# - Demonstrates which models built from previous Generations fare when it comes to the unseen Pokémon.
#
# Assess the Impact of Model Complexity:
# - This compares Model 6 and Model 7 to show readers that the level of generalization differs when the model becomes complex.
#
# Highlight Dataset Diversity:
# - Shows that training from all Generations (Generations 1–5) results in improved generality in comparison to training from only Generation 1.

# %% [markdown]
# #### Conclusion:
# This case shows us that we need better diversity and that training models should be simple. Explicit training on a single Generation may capture little about the remaining patterns which can lead to poor forecast on the future Generations. This work shows that models trained on previous Generations (1–5) learn to generalize better to Generation 6. Also, models such as Model 6 are relatively more stable and perform better across the different folds than relatively complex models such as Model 7 which may overtrain the data.
