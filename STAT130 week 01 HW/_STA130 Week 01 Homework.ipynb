# %%
import pandas as pd

# Load your dataset
url = "https://raw.githubusercontent.com/datasets/commodity-prices/master/data/commodity-prices.csv"
com = pd.read_csv(url)

# %%
com
# Out:
#            Date  All Commodity Price Index  Non-Fuel Price Index  \
# 0    1980-01-01                        NaN                   NaN
# 1    1980-02-01                        NaN                   NaN
# 2    1980-03-01                        NaN                   NaN
# 3    1980-04-01                        NaN                   NaN
# 4    1980-05-01                        NaN                   NaN
# ..          ...                        ...                   ...
# 445  2017-02-01                 118.615999            145.232866
# 446  2017-03-01                 113.314945            142.940071
# 447  2017-04-01                 113.226876            138.528012
# 448  2017-05-01                 110.589462            138.865166
# 449  2017-06-01                 106.840977            138.622118
#
#      Food and Beverage Price Index  Food Price Index  Beverage Price Index  \
# 0                              NaN               NaN            189.310021
# ...

# %%
com.shape
# Out:
# (450, 64)

# %%
com.describe()
# Out:
#        All Commodity Price Index  Non-Fuel Price Index  \
# count                 306.000000            318.000000
# mean                  100.796302            115.066289
# std                    50.113245             35.294688
# min                    41.977549             70.367583
# 25%                    58.535131             84.577086
# 50%                    83.431606            100.435879
# 75%                   134.400893            142.700852
# max                   220.030251            206.483885
#
#        Food and Beverage Price Index  Food Price Index  Beverage Price Index  \
# count                     318.000000        318.000000            450.000000
# mean                      119.879623        119.596359            125.658430
# std                        33.364661         33.166343             37.433449
# min                        75.831061         76.044302             60.645581
# 25%                        94.558640         95.624823             90.239453
# ...

# %%
com.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450 entries, 0 to 449
# Data columns (total 64 columns):
#  #   Column                                                           Non-Null Count  Dtype
# ---  ------                                                           --------------  -----
#  0   Date                                                             450 non-null    object
#  1   All Commodity Price Index                                        306 non-null    float64
#  2   Non-Fuel Price Index                                             318 non-null    float64
#  3   Food and Beverage Price Index                                    318 non-null    float64
#  4   Food Price Index                                                 318 non-null    float64
#  5   Beverage Price Index                                             450 non-null    float64
#  6   Industrial Inputs Price Index                                    450 non-null    float64
# ...

# %%
com['Date'].value_counts()
# Out:
# Date
# 1980-01-01    1
# 2008-02-01    1
# 2005-08-01    1
# 2005-07-01    1
# 2005-06-01    1
#              ..
# 1992-03-01    1
# 1992-02-01    1
# 1992-01-01    1
# 1991-12-01    1
# 2017-06-01    1
# Name: count, Length: 450, dtype: int64

# %%
com['All Commodity Price Index'].describe()
# Out:
# count    306.000000
# mean     100.796302
# std       50.113245
# min       41.977549
# 25%       58.535131
# 50%       83.431606
# 75%      134.400893
# max      220.030251
# Name: All Commodity Price Index, dtype: float64

# %%
com.isnull().sum()
# Out:
# Date                               0
# All Commodity Price Index        144
# Non-Fuel Price Index             132
# Food and Beverage Price Index    132
# Food Price Index                 132
#                                 ...
# Uranium                            0
# Wheat                              0
# Wool coarse                        0
# Wool fine                          0
# Zinc                               0
# Length: 64, dtype: int64

# %%
com = com.dropna()

# %%
del.com['col']
# Out:
#   Cell In[7], line 1
#     del.com['col']
#        ^
# SyntaxError: invalid syntax

# %%
com.describe()
# Out:
#        All Commodity Price Index  Non-Fuel Price Index  \
# count                 306.000000            318.000000
# mean                  100.796302            115.066289
# std                    50.113245             35.294688
# min                    41.977549             70.367583
# 25%                    58.535131             84.577086
# 50%                    83.431606            100.435879
# 75%                   134.400893            142.700852
# max                   220.030251            206.483885
#
#        Food and Beverage Price Index  Food Price Index  Beverage Price Index  \
# count                     318.000000        318.000000            450.000000
# mean                      119.879623        119.596359            125.658430
# std                        33.364661         33.166343             37.433449
# min                        75.831061         76.044302             60.645581
# 25%                        94.558640         95.624823             90.239453
# ...

# %%
com.describe()
# Out:
#        All Commodity Price Index  Non-Fuel Price Index  \
# count                 306.000000            306.000000
# mean                  100.796302            116.171481
# std                    50.113245             35.521939
# min                    41.977549             70.367583
# 25%                    58.535131             85.202530
# 50%                    83.431606            101.042369
# 75%                   134.400893            143.278330
# max                   220.030251            206.483885
#
#        Food and Beverage Price Index  Food Price Index  Beverage Price Index  \
# count                     306.000000        306.000000            306.000000
# mean                      120.745196        120.377035            124.143664
# std                        33.708971         33.559628             40.205564
# min                        75.831061         76.044302             60.645581
# 25%                        94.567236         95.479311             87.017161
# ...

# %%
import neon as pdf

url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv"

dp = pd.read_csv(url)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import neon as pdf
#       3 url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv"
#       5 dp = pd.read_csv(url)
#
# ModuleNotFoundError: No module named 'neon'

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv"

df = pd.read_csv(url)

# %%
com
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 com
#
# NameError: name 'com' is not defined

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
com
# Out:
#            Date  All Commodity Price Index  Non-Fuel Price Index  \
# 0    1980-01-01                        NaN                   NaN
# 1    1980-02-01                        NaN                   NaN
# 2    1980-03-01                        NaN                   NaN
# 3    1980-04-01                        NaN                   NaN
# 4    1980-05-01                        NaN                   NaN
# ..          ...                        ...                   ...
# 445  2017-02-01                 118.615999            145.232866
# 446  2017-03-01                 113.314945            142.940071
# 447  2017-04-01                 113.226876            138.528012
# 448  2017-05-01                 110.589462            138.865166
# 449  2017-06-01                 106.840977            138.622118
#
#      Food and Beverage Price Index  Food Price Index  Beverage Price Index  \
# 0                              NaN               NaN            189.310021
# ...

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
df.groupby("age")["fare"].describe()
# Out:
#        count      mean        std       min       25%       50%       75%  \
# age
# 0.42     1.0    8.5167        NaN    8.5167    8.5167    8.5167    8.5167
# 0.67     1.0   14.5000        NaN   14.5000   14.5000   14.5000   14.5000
# 0.75     2.0   19.2583   0.000000   19.2583   19.2583   19.2583   19.2583
# 0.83     2.0   23.8750   7.247845   18.7500   21.3125   23.8750   26.4375
# 0.92     1.0  151.5500        NaN  151.5500  151.5500  151.5500  151.5500
# ...      ...       ...        ...       ...       ...       ...       ...
# 70.00    2.0   40.7500  42.779960   10.5000   25.6250   40.7500   55.8750
# 70.50    1.0    7.7500        NaN    7.7500    7.7500    7.7500    7.7500
# 71.00    2.0   42.0792  10.500536   34.6542   38.3667   42.0792   45.7917
# 74.00    1.0    7.7750        NaN    7.7750    7.7750    7.7750    7.7750
# 80.00    1.0   30.0000        NaN   30.0000   30.0000   30.0000   30.0000
#
#             max
# age
# 0.42     8.5167
# 0.67    14.5000
# ...

# %%
df.groupby("sibsp")["age"].describe()
# Out:
#        count       mean        std   min    25%   50%    75%   max
# sibsp
# 0      471.0  31.397558  13.647767  0.42  22.00  29.0  39.00  80.0
# 1      183.0  30.089727  14.645033  0.67  20.00  30.0  39.00  70.0
# 2       25.0  22.620000  14.679230  0.75  16.00  23.0  28.00  53.0
# 3       12.0  13.916667  11.317391  2.00   3.75   9.5  23.25  33.0
# 4       18.0   7.055556   4.880601  1.00   3.25   6.5   9.00  17.0
# 5        5.0  10.200000   5.805170  1.00   9.00  11.0  14.00  16.0
# 8        0.0        NaN        NaN   NaN    NaN   NaN    NaN   NaN

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.groupby("Sex")["age"].describe()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 df.groupby("Sex")["age"].describe()
#
# File /opt/conda/lib/python3.11/site-packages/pandas/core/frame.py:8869, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    8866 if level is None and by is None:
#    8867     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 8869 return DataFrameGroupBy(
#    8870     obj=self,
#    8871     keys=by,
#    8872     axis=axis,
#    8873     level=level,
#    8874     as_index=as_index,
#    8875     sort=sort,
#    8876     group_keys=group_keys,
#    8877     observed=observed,
#    8878     dropna=dropna,
#    8879 )
#
# ...

# %%
df.groupby("sex")["age"].describe()
# Out:
#         count       mean        std   min   25%   50%   75%   max
# sex
# female  261.0  27.915709  14.110146  0.75  18.0  27.0  37.0  63.0
# male    453.0  30.726645  14.678201  0.42  21.0  29.0  39.0  80.0
