# %% [markdown]
# # STA130 Homework 05

# %% [markdown]
# A. Watch this first pre-lecture video ("Hypothesis testing. Null vs alternative") addressing the question "What is a hypothesis?"

# %%
from IPython.display import YouTubeVideo
# First pre-lecture video: 
# "Hypothesis testing. Null vs alternative
# https://www.youtube.com/watch?v=ZzeXCKd5a18
YouTubeVideo('ZzeXCKd5a18', width=800, height=500)

# %% [markdown]
# B. Watch this second pre-lecture video ("What is a p-value") providing an intuitivie introduction to p-values

# %%
from IPython.display import YouTubeVideo
# Second pre-lecture video
# "What is a p-value"
# https://www.youtube.com/watch?v=9jW9G8MO4PQ
YouTubeVideo('9jW9G8MO4PQ', width=800, height=500)

# %% [markdown]
# ### 1. The "first pre-lecture video" (above) describes hypothesis testing as addressing "an idea that can be tested", and the end of the video then discusses what our actual intended purpose in setting up a null hypothesis is. What is the key factor that makes the difference between ideas that can, and cannot be examined and tested statistically? What would you describe is the key "criteria" defining what a good null hypothesis is? And what is the difference between a null hypothesis and an alternative hypothesis in the context of hypothesis testing? Answer these questions with concise explanations in your own words.

# %% [markdown]
# - when it comes to determining if we can create a hypothesis or not, the first aspect is that for a hypothesis to stand we need to set it against something, in the sense we are testing the data to where we can make a conclusion.The next aspect is for the samples we are gonna compare actually exist, similar to the example given in video, if we compare the terms of Hillary Clinton and Trump we can't since clinton was never a president so we can't really compare her term when it doesn't even exist. In overview we need two aspects that can be tested, where we can test for its validity or not, like the court of law, we need proof.

# %% [markdown]
# - When thinking of a good null hypothesis, it is one that is specific and testable. It's given in a way that there isn't room for variability, it's clear and concise to the point. You don't want a hypothesis where we aren't sure where its premises are unknown.

# %% [markdown]
# - A null hypothesis is the hypothesis of which we have to prove right or wrong. In other words it is the aspect we are testing for to see if its true or false. This is where the alternative hypothesis finds its way, this hypothesis is the alternative to the null hypothesis, or its counter. Note that we don't test for the alternative hypothesis, since if the null hypothesis fails we just imply that the alternative hypothesis is true.

# %% [markdown]
# ### 2. Towards the end of the "first pre-lecture" video (above) it is stated that, "It is important to note that outcomes of tests refer to the population parameter, rather than the sample statistic! As such, the result that we get is for the population." In terms of the distinctions between the concepts of xᵢ's, x̄ ,μ , and μ₀, how would you describe what the sentence above means? Explain this concisely in your own words for a "non-statsitical" audience, defining the technical statistical terminology you use in your answer.

# %% [markdown]
# - xᵢ refers to the indevidual data point or values in a sample. lets say you have a sample of the number of students in each class, the number of students will be the xᵢ we are refering to.

# %% [markdown]
# - x̄ or x-bar is referring to the sample mean for a sample of data we have. the mean for the xᵢ values we were explaining in the previous explanation. It describes an observation in a sample.

# %% [markdown]
# - μ (mu) refers to the population mean, this is usually referred to as the true mean. though note that we can't really compute this value since we can never really get a full survey or measure for the whole population. Hence it's usually estimated.

# %% [markdown]
# - μ₀ (mu-zero) is referring to the hypothesized mean for the null hypothesis. In other words, it's the value we presume to be true for our null hypothesis. An assumption where the population mean might be.

# %% [markdown]
# ### 3. The second "Pre-lecture" video (above) explains that we "imagine a world where the null hypothesis is true" when calculating a p-value? Explain why this is in your own words in a way that makes the most sense to you.

# %% [markdown]
# - we assume it's true since when we think of the p-value, it's a value that represents how many values meet the null hypothesis condition. To get such a value, we need to test for how many values meet the precondition of the null hypothesis. By doing so we have to presume the hypothesis is true. Like said in the video, p-value is like a court of law , it's true until proven false.

# %% [markdown]
# ### 4. The second "Pre-lecture" video (above) describes suggest that a smaller p-value makes the null hypothesis look more ridiculous. Explain why this is in your own words in a way that makes the most sense to you, clarifying the meaning of any technical statistical terminology you use in your answer.

# %% [markdown]
# - A smaller p-value just tells us that less than 50% of the values we are testing met the condition for the null hypothesis. so if the value is smaller we just know that there were less samples that meet the conditions for the null hypothesis when it was tested, and the opposite will be true. When addressing this explanation from a statistics point of view, the p-value is a comparison of the mean difference to the sample means. The number of those means that lie between those parameters, will be divided by the overall number of samples,this will be evaluated to be the p-value, a percentage like value.the smaller the value the smaller amount of samples from the over samples met the null hypothesis condition.

# %% [markdown]
# ### 5. Güntürkün (2003) recorded how kissing couples tilt their heads. 80 out of 124 couples, or 64.5% tilted their heads to the right. Simulate a p-value using a "50/50 coin-flipping" model for the assumption of the null hypothesis H₀  that the population of humans don't have left or right head tilt tendencies when kissing, and use the table below to determine the level of evidence we have against H₀.

# %% [markdown]
# - Let us first start by assuming that the null hypothesis holds true where there is a 50/50 chance for the couple who tilt their heads left or right. We then proceed to take our sample of 124 couples and through bootstrapping generate a great number of simulations of the sample given. We then forget the data and compare our sample means from all the simulations to the difference mean from the original sample. We then proceed to calculate the p-value, if we find the p-value to be smaller than 0.05 we can assume there is a Moderate evidence that these hypotheses might be false, and hence we can not presume that it is the full truth.

# %% [markdown]
# ### 6. Can a smaller p-value definitively prove that the null hypothesis is false? Is it possible to definitively prove that Fido (from the "second pre-lecture video") is innocent using a p-value? Is it possible to difinitively prove that Fido is guilty using a p-value? How low or high does a p-value have to be to definitely prove one or the other? Explain this concisely in your own words.

# %% [markdown]
# - A p-value can never really prove a hypothesis to be true or false. What it can do is give us strong evidence that it might be true or not. When we refer to the p-value, we need to understand that p stands for probability, not statistical value. What I'm hinting at =, if there isn't full certainty it's all just high, low or moderate probability of hypothesis being true.

# %% [markdown]
# - Now knowing the what was previously stated, we can aproximate that, if a p-value is greater than 0.05 to where it gets closer to 1 the higher the probability for Fido to be guilty. in contrast a value starting from 0.05 and as it gets closer to 0 we get more certain that Fido is inocent.

# %% [markdown]
# ### 7. In the second half of the "first pre-lecture video" the concept of a "one sided" (or "one tailed") test is introduced in contrast to a "two sided" (or "two tailed") test. Work with a ChatBot to adjust the code from "Demo II of the Week 5 TUT" (which revisits the "Vaccine Data Analysis Assignment" from Week 04 HW "Question 8") in order to compute a p-value for a "one sided" (or "one tailed") hypothesis test rather than the "two sided" (or "two tailed") version it provides. Describe (perhaps with the help of your ChatBot) what changed in the code; how this changes the interpretation of the hypothesis test; and whether or not we should indeed expect the p-value to be smaller in the "one tailed" versus "two tailed" analysis.`

# %%
import numpy as np
import matplotlib.pyplot as plt

# Data for Initial and Final Health Scores
initial_health_scores = np.array([84, 78, 83, 81, 81, 80, 79, 85, 76, 83])
final_health_scores = np.array([86, 86, 80, 86, 84, 86, 86, 82, 83, 84])

# Number of bootstrap iterations
n_iterations = 10000
np.random.seed(42)  # For reproducibility

# Function to calculate the mean difference between initial and final health scores
def mean_difference(sample_initial, sample_final):
    return np.mean(sample_final) - np.mean(sample_initial)

# Observed mean difference in the actual data
observed_mean_diff = mean_difference(initial_health_scores, final_health_scores)

# Bootstrap process
bootstrap_diffs = []
for _ in range(n_iterations):
    # Resample with replacement from the original data
    bootstrap_initial = np.random.choice(initial_health_scores, size=len(initial_health_scores), replace=True)
    bootstrap_final = np.random.choice(final_health_scores, size=len(final_health_scores), replace=True)
    
    # Calculate the mean difference for the resampled data
    bootstrap_diffs.append(mean_difference(bootstrap_initial, bootstrap_final))

# Convert the bootstrap differences to a numpy array
bootstrap_diffs = np.array(bootstrap_diffs)

# Calculate the 95% confidence interval
lower_bound = np.percentile(bootstrap_diffs, 2.5)
upper_bound = np.percentile(bootstrap_diffs, 97.5)

# p-value calculation: proportion of bootstrap samples where the mean difference is >= observed difference
p_value = np.mean(bootstrap_diffs >= observed_mean_diff)

# Output the results
print(f"Observed mean difference: {observed_mean_diff}")
print(f"95% Confidence Interval: [{lower_bound}, {upper_bound}]")
print(f"p-value: {p_value}")

# Conclusion: Reject or fail to reject the null hypothesis
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: There is a significant effect of the vaccine.")
else:
    print("Fail to reject the null hypothesis: There is no significant effect of the vaccine.")

# Adding histograms to visualize the bootstrap distribution
plt.figure(figsize=(20, 10))
plt.hist(bootstrap_diffs, bins=30, alpha=0.7, color='b', label='Bootstrap Mean Differences')

# Plot the observed mean difference
plt.axvline(observed_mean_diff, color='r', linestyle='dashed', linewidth=2, label='Observed Mean Difference')
plt.axvspan(lower_bound, upper_bound, color='purple', alpha=0.3, label='Confidence Interval')

# Adding titles and labels
plt.title('Bootstrap Distribution of Mean Differences')
plt.xlabel('Mean Difference (Final - Initial)')
plt.ylabel('Frequency')
plt.legend()

# Display the plot
plt.show()
# Out:
# Observed mean difference: 3.299999999999997
# 95% Confidence Interval: [1.2000000000000028, 5.3999999999999915]
# p-value: 0.5227
# Fail to reject the null hypothesis: There is no significant effect of the vaccine.

# %% [markdown]
# - when it comes to the difference between a onesided p-value and a two-sided p-value:
# - One-sided p-value: This method takes a value and compares it to the value of the original mean difference. For our case, we are only considering values greater than the mean difference for patients who experienced an increase in health, which is 0.8.
# - two-sided p-value: Take the variance of data within a bracket. In this case, the bootstrap means are compared to the parameter and not a value. In this case, we take the interval of 0.3 to 0.8 as a range for where we are checking for the percentile of means that lie in the parameter.
# - What to expect from the p-value: A one-sided test will usually produce a smaller value than a two-sided test because you are only considering one tail of the distribution. Since we include both negative and positive values for our probability trends, we expect the p-value to be greater.

# %% [markdown]
# ##### The change in code:

# %% [markdown]
# ###### One-sided:

# %% [markdown]
# p_value = np.mean(bootstrap_diffs >= observed_mean_diff)

# %% [markdown]
# ###### two-sided:

# %% [markdown]
# p_value = 2 * min(np.mean(bootstrap_diffs >= observed_mean_diff), np.mean(bootstrap_diffs <= observed_mean_diff))

# %% [markdown]
# ### 8. Complete the following assignment.

# %% [markdown]
# ##### Code:

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
import math

# Input data
correct_count = 49
sample_size = 80
p_null = 0.5  # Null hypothesis proportion (random guessing)

# Calculate the sample proportion
p_hat = correct_count / sample_size

# Calculate the standard error
standard_error = math.sqrt((p_null * (1 - p_null)) / sample_size)

# Bootstrap process
n_iterations = 10000
np.random.seed(42)  # For reproducibility

# Generate bootstrap samples under the null hypothesis (p_null = 0.5)
bootstrap_proportions = []
for _ in range(n_iterations):
    # Simulate a sample of size `sample_size` with probability `p_null` for correct identification
    bootstrap_sample = np.random.binomial(n=sample_size, p=p_null)
    bootstrap_proportion = bootstrap_sample / sample_size
    bootstrap_proportions.append(bootstrap_proportion)

# Convert to a numpy array
bootstrap_proportions = np.array(bootstrap_proportions)

# Calculate the bootstrap p-value (two-sided)
extreme_count = np.sum((bootstrap_proportions >= p_hat) | (bootstrap_proportions <= 1 - p_hat))
bootstrap_p_value = extreme_count / n_iterations

# Create a histogram of bootstrap proportions
plt.hist(bootstrap_proportions, bins=30, density=True, alpha=0.7, color='blue', edgecolor='black')
plt.axvline(p_hat, color='red', linestyle='dashed', linewidth=2, label=f'Observed p̂ = {p_hat:.2f}')
plt.axvline((1-p_hat), color='red', linestyle='dashed', linewidth=2, label=f'Observed p̂ = {p_hat:.2f}')
plt.axvline(0.5, color='black', linestyle='dashed', linewidth=2, label=f'Observed p̂ = {p_hat:.2f}')
plt.axvspan(p_hat, (1-p_hat), color='purple', alpha=0.3, label='two-sided p-value')
plt.title('Bootstrap Distribution of Proportions')
plt.xlabel('Proportion')
plt.ylabel('Density')
plt.legend()
plt.grid(True)
plt.show()

# Output the results of the Z-test
print(f"Sample proportion (p̂): {p_hat}")
print(f"Standard Error: {standard_error}")
print(f"Two-tailed p-value (Bootstrap): {bootstrap_p_value}")

# Conclusion using the bootstrap p-value
alpha = 0.05
if bootstrap_p_value < alpha:
    print("Reject the null hypothesis (Bootstrap): There is evidence that students can identify the pour order better than random guessing.")
else:
    print("Fail to reject the null hypothesis (Bootstrap): There is no evidence that students can identify the pour order better than random guessing.")
# Out:
# Sample proportion (p̂): 0.6125
# Standard Error: 0.05590169943749474
# Two-tailed p-value (Bootstrap): 0.0441
# Reject the null hypothesis (Bootstrap): There is evidence that students can identify the pour order better than random guessing.

# %% [markdown]
# Introduction to the problem:
#
# - We are addressing the plausibility of a milk tea having a different taste depending on the way it was prepared. We explore the population of passionate tea lovers who are the stat130 students. We take a sample of 80 students from the overall population of the full stat130 class. We found that from those 80 students, 49 students correctly identified the milk tea preparation method. The hypothesis to prove, is the chance of selecting the right milk tea preparation method merely luck or is there a taste difference. This will be solved through the use of the p-value. Description of the population (and sample) and
#
# parameter of interest (and corresponding observed test statistic):
#
# - Populations: Refers to the entire number of Stat130 students who can take the milktea test.
# - Sample: this will refer to the sample of 80 students out of all the stat130 students who took the milk tea test.
# - parameter of interest: The portion of students who can identify the different poured teas correctly. Null hypotheses:
#
# Null hypothysis:
#
# - when referring to the null hypothesis in this case we are referring to the possibility that the chance of the stat130 students is at 50/50. so the number of students that correctly identify the selection of poured milk tea is greater than 0.5. H0: p > 0.5 where the true portion of students correctly identified the two types of poured teas.
#
# Alternative Hypothesis:
#
# - The portion of students who correctly identified the correct type of poured tea. We are referring to their H1 p >=0.5, where there will be a probability that the students' answers were at random and the chance of them choosing the correct poured tea is luck.
#
# Process:
#
# - We take the sample and find the average difference which is that 49/80 students correctly identified the correct tea. This gives us a p= 0.6125. we then proceed to run bootstrap on the following sample. We take the means that display a similar mean that lie between the two sided p-value from the range of 0.6125 to 0.3875. We take the number of means that dont lie in that range in reference to all means. Through this process we get a value of 0.0441, from the previous question we know that if p-value <0.05 we can conclude with confidence we can say that the null hypothesis can be dismissed.

# %% [markdown]
# ### 9. Have you reviewed the course wiki-textbook and interacted with a ChatBot (or, if that wasn't sufficient, real people in the course piazza discussion board or TA office hours) to help you understand all the material in the tutorial and lecture that you didn't quite follow when you first saw it?

# %% [markdown]
# - went over the all the material as needed!
