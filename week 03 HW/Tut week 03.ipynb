# %% [markdown]
# # STA130 TUT 03 HW

# %% [markdown]
# ## Pre-Lecture

# %% [markdown]
# ### 1. Use fig.add_[h/v]line() and fig.add_[h/v]rect() to mark, respspectively, location (mean and median) and scale (range, interquartile range, and a range defined by two standard deviations away from the mean in both directions) of flipper_length_mm for each species onto plotly histograms of flipper_length_mm for each species in the penguins dataset

# %% [markdown]
# [Chatbot log](https://chatgpt.com/share/66f5e51c-74a0-8006-937e-5a24192d820d)

# %%
import plotly.express as px
import plotly.graph_objects as go
import seaborn as sns
import pandas as pd
peng = pd.read_csv("https://raw.githubusercontent.com/mwaskom/seaborn-data/master/penguins.csv")
peng
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# ...

# %%
ping.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %%
fig = go.Figure()

# %%
fig = px.histogram(peng, color="species", x="flipper_length_mm")
fig.show(renderer="png")

# %%
mean = peng['flipper_length_mm'].mean()
median = peng['flipper_length_mm'].median()
std = peng['flipper_length_mm'].std()

# %%
    fig.add_vline(x=mean, line_width=3, line_dash="dash", line_color="green")
    fig.add_vline(x=median, line_width=3, line_dash="dash", line_color="green")
    fig.show(renderer="png")

# %%
min_value = peng['flipper_length_mm'].min()
max_value = peng['flipper_length_mm'].max()
q1 = peng['flipper_length_mm'].quantile(0.25)
q3 = peng['flipper_length_mm'].quantile(0.75)

# %%
fig.add_vrect(x0=q3, x1=max_value)
fig.add_vrect(x0=min_value, x1=q1)
fig.show(renderer="png")

# %% [markdown]
# ### 2. Transition your ChatBot session from the previous problem to repeat the previous problem, but this time using seaborn kernel density estimation (KDE) plots to produce the desired figures organized in row of three plots

# %% [markdown]
# [Chatbot log](https://chatgpt.com/share/66f5e51c-74a0-8006-937e-5a24192d820d)

# %%
import plotly.express as px
import plotly.graph_objects as go
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
pen = pd.read_csv("https://raw.githubusercontent.com/mwaskom/seaborn-data/master/penguins.csv")
pen
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# ...

# %%
sns.kdeplot(data= pen, x='flipper_length_mm', fill=True, color='blue')

plt.title('KDE Plot of Flipper Length in Penguins')
plt.xlabel('Flipper Length (mm)')
plt.ylabel('Density')

plt.savefig("kde_flipper_length.png", format="png", dpi=300)

plt.show()

# %%
mean_val = pen['flipper_length_mm'].mean()
median_val = pen['flipper_length_mm'].median()
min_val = pen['flipper_length_mm'].min()
max_val = pen['flipper_length_mm'].max()
q1 = pen['flipper_length_mm'].quantile(0.25)
q3 = pen['flipper_length_mm'].quantile(0.75)
std_val = pen['flipper_length_mm'].std()

# Create a KDE plot using Seaborn
sns.kdeplot(data=pen, x='flipper_length_mm', fill=True, color='blue')

# Add vertical lines for mean, median, and other statistics
plt.axvline(mean_val, color='green', linestyle='--', label='Mean')
plt.axvline(median_val, color='blue', linestyle='--', label='Median')
plt.axvline(min_val, color='red', linestyle=':', label='Min')
plt.axvline(max_val, color='red', linestyle=':', label='Max')
plt.axvline(q1, color='orange', linestyle='-.', label='25th Percentile (Q1)')
plt.axvline(q3, color='orange', linestyle='-.', label='75th Percentile (Q3)')
plt.axvline(mean_val - 2*std_val, color='purple', linestyle=':', label='Mean - 2*STD')
plt.axvline(mean_val + 2*std_val, color='purple', linestyle=':', label='Mean + 2*STD')

# Add title, labels, and legend using Matplotlib
plt.title('KDE Plot of Flipper Length in Penguins with Key Statistics')
plt.xlabel('Flipper Length (mm)')
plt.ylabel('Density')
plt.legend(loc='upper right')

plt.savefig("kde_flipper_length.png", format="png", dpi=300)
# Display the plot
plt.show()

# %% [markdown]
# ### 3.  Search online for some images of box plots, histograms, and kernel density estimators (perhaps for the same data set); describe to a ChatBot what you think the contrasting descriptions of these three "data distribution" visualization methods are; and then see if the ChatBot agrees and what "pros and cons" list of these three "data distribution" visualization methods your ChatBot can come up with; finally, describe your preference for one or the other and your rationale for this preference

# %% [markdown]
# - My preference would be the kernel density due to many reasons, one of them is its simplicity and ease to look at. It also gives a smooth data set that curves between the different values. This in contrast to the boc plot where the data set might be clear and easy to understand the look of the data set does not look as sem=emingly detailed as a KDE. Secondly, is how defined it is, locating the modes in the graph are quite easy compared to the histogram for me specifically. None the less a believe all are great ways to summarize our data in graphs but I prefer the KDE over all different methods.

# %% [markdown]
# [ChatBot log](https://chatgpt.com/share/66f5edc3-892c-8006-b629-d8935bc909cd)

# %% [markdown]
# ### 4. Run the code below and look at the resulting figure of distrubutions and then answer the following questions

# %%
from scipy import stats
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import numpy as np

n = 1500
data1 = stats.uniform.rvs(0, 10, size=n)
data2 = stats.norm.rvs(5, 1.5, size=n)
data3 = np.r_[stats.norm.rvs(2, 0.25, size=int(n/2)), stats.norm.rvs(8, 0.5, size=int(n/2))]
data4 = stats.norm.rvs(6, 0.5, size=n)

fig = make_subplots(rows=1, cols=4)

fig.add_trace(go.Histogram(x=data1, name='A', nbinsx=30, marker=dict(line=dict(color='black', width=1))), row=1, col=1)
fig.add_trace(go.Histogram(x=data2, name='B', nbinsx=15, marker=dict(line=dict(color='black', width=1))), row=1, col=2)
fig.add_trace(go.Histogram(x=data3, name='C', nbinsx=45, marker=dict(line=dict(color='black', width=1))), row=1, col=3)
fig.add_trace(go.Histogram(x=data4, name='D', nbinsx=15, marker=dict(line=dict(color='black', width=1))), row=1, col=4)

fig.update_layout(height=300, width=750, title_text="Row of Histograms")
fig.update_xaxes(title_text="A", row=1, col=1)
fig.update_xaxes(title_text="B", row=1, col=2)
fig.update_xaxes(title_text="C", row=1, col=3)
fig.update_xaxes(title_text="D", row=1, col=4)
fig.update_xaxes(range=[-0.5, 10.5])

for trace in fig.data:
    trace.xbins = dict(start=0, end=10)
    

fig.show(renderer="png")

# %% [markdown]
# #### 1-\
# - B and D have similar means and similar variances
# #### 2-\
# - A and B have similar means but quite different variances
# #### 3-\
# - C and D have similar variances but quite different means
# #### 4-\
# - A and C have quite different means and quite different variances

# %% [markdown]
# ### 5. Start a new ChatBot session to explore the general relationship between the mean and median and "right" and "left" skewness (and why this is); what the following code does and how it works; and then explain (in your own words) the relationship between the mean and median and "right" and "left" skewness and what causes this, using and extending the code to demonstrate your explanation through a sequence of notebook cells.

# %% [markdown]
#  - right skewness: Usually a right skewed data frame will have a long tail on the right. the mean will be greater than the median in these cases. for the code sample code 1 is the one skewed right. Mean > Median > Mode.
#
#
# - left skewness Usually a right skewed data frame will have a long tail on the left. the median will be greater than the mean. in the code given case 2 By multiplying the gamma-distributed values by -1, mirrors all the values to the left. Hense giving us a left skewed version of case 1.

# %% [markdown]
# [ChatBot log](https://chatgpt.com/share/66f5f450-89c4-8006-8220-34c3b2f93f9e)

# %% [markdown]
# ### 6. Go find an interesting dataset and use summary statistics and visualizations to understand and demonstate some interesting aspects of the data

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

df = sns.load_dataset('flights')
df
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
plt.figure(figsize=(10,6))
sns.lineplot(x='year', y='passengers', hue='month', data=df)
plt.title('Number of Passengers Over Time')
plt.xlabel('Year')
plt.ylabel('Number of Passengers')
plt.savefig("flights_plot.png", format="png")
plt.savefig("flights_plot.png", format="png")
plt.show()

mean_val = df['passengers'].mean()
median_val = df['passengers'].median()
min_val = df['passengers'].min()
max_val = df['passengers'].max()
q1 = df['passengers'].quantile(0.25)
q3 = df['passengers'].quantile(0.75)
std_val = df['passengers'].std()

# %%
fig = px.histogram(df, x='month', y= 'passengers', title='Histogram of Passengers', color='year')
fig.show(renderer="png")

# %%
fig2 = px.box(df, x='month', y='passengers', title='Boxplot of Passengers by Month')
fig2.show(renderer="png")

# %%
sns.kdeplot(data=df, x='passengers', hue='month', shade=True)

plt.title('Kernel Density Plot of Passengers')
plt.xlabel('Months')
plt.ylabel('Passengers')
# Out:
# /tmp/ipykernel_53/1063478413.py:1: FutureWarning:
#
#
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
# Text(0, 0.5, 'Passengers')

# %% [markdown]
# [ChatBot log](https://chatgpt.com/share/66f60a11-2b84-8006-a40a-242d9240faf7)

# %% [markdown]
# ### 7. Watch the classic Gapminder Video, then have a look at the plotly version and recreate the animation (perhaps after optionally exploring and changing the style, if you wish)

# %%
import plotly.graph_objects as go

import pandas as pd

url = "https://raw.githubusercontent.com/plotly/datasets/master/gapminderDataFiveYear.csv"
dataset = pd.read_csv(url)

years = ["1952", "1962", "1967", "1972", "1977", "1982", "1987", "1992", "1997", "2002",
         "2007"]

# make list of continents
continents = []
for continent in dataset["continent"]:
    if continent not in continents:
        continents.append(continent)
# make figure
fig_dict = {
    "data": [],
    "layout": {},
    "frames": []
}

# fill in most of layout
fig_dict["layout"]["xaxis"] = {"range": [30, 85], "title": "Life Expectancy"}
fig_dict["layout"]["yaxis"] = {"title": "GDP per Capita", "type": "log"}
fig_dict["layout"]["hovermode"] = "closest"
fig_dict["layout"]["updatemenus"] = [
    {
        "buttons": [
            {
                "args": [None, {"frame": {"duration": 500, "redraw": False},
                                "fromcurrent": True, "transition": {"duration": 300,
                                                                    "easing": "quadratic-in-out"}}],
                "label": "Play",
                "method": "animate"
            },
            {
                "args": [[None], {"frame": {"duration": 0, "redraw": False},
                                  "mode": "immediate",
                                  "transition": {"duration": 0}}],
                "label": "Pause",
                "method": "animate"
            }
        ],
        "direction": "left",
        "pad": {"r": 10, "t": 87},
        "showactive": False,
        "type": "buttons",
        "x": 0.1,
        "xanchor": "right",
        "y": 0,
        "yanchor": "top"
    }
]

sliders_dict = {
    "active": 0,
    "yanchor": "top",
    "xanchor": "left",
    "currentvalue": {
        "font": {"size": 20},
        "prefix": "Year:",
        "visible": True,
        "xanchor": "right"
    },
    "transition": {"duration": 300, "easing": "cubic-in-out"},
    "pad": {"b": 10, "t": 50},
    "len": 0.9,
    "x": 0.1,
    "y": 0,
    "steps": []
}

# make data
year = 1952
for continent in continents:
    dataset_by_year = dataset[dataset["year"] == year]
    dataset_by_year_and_cont = dataset_by_year[
        dataset_by_year["continent"] == continent]

    data_dict = {
        "x": list(dataset_by_year_and_cont["lifeExp"]),
        "y": list(dataset_by_year_and_cont["gdpPercap"]),
        "mode": "markers",
        "text": list(dataset_by_year_and_cont["country"]),
        "marker": {
            "sizemode": "area",
            "sizeref": 200000,
            "size": list(dataset_by_year_and_cont["pop"])
        },
        "name": continent
    }
    fig_dict["data"].append(data_dict)

# make frames
for year in years:
    frame = {"data": [], "name": str(year)}
    for continent in continents:
        dataset_by_year = dataset[dataset["year"] == int(year)]
        dataset_by_year_and_cont = dataset_by_year[
            dataset_by_year["continent"] == continent]

        data_dict = {
            "x": list(dataset_by_year_and_cont["lifeExp"]),
            "y": list(dataset_by_year_and_cont["gdpPercap"]),
            "mode": "markers",
            "text": list(dataset_by_year_and_cont["country"]),
            "marker": {
                "sizemode": "area",
                "sizeref": 200000,
                "size": list(dataset_by_year_and_cont["pop"])
            },
            "name": continent
        }
        frame["data"].append(data_dict)

    fig_dict["frames"].append(frame)
    slider_step = {"args": [
        [year],
        {"frame": {"duration": 300, "redraw": False},
         "mode": "immediate",
         "transition": {"duration": 300}}
    ],
        "label": year,
        "method": "animate"}
    sliders_dict["steps"].append(slider_step)


fig_dict["layout"]["sliders"] = [sliders_dict]

fig = go.Figure(fig_dict)

fig.show(renderer="png")

# %%
import plotly.graph_objects as go
import pandas as pd

# Load dataset
url = "https://raw.githubusercontent.com/plotly/datasets/master/gapminderDataFiveYear.csv"
dataset = pd.read_csv(url)

# List of years to animate over
years = ["1952", "1962", "1967", "1972", "1977", "1982", "1987", "1992", "1997", "2002", "2007"]

# Unique list of continents
continents = dataset["continent"].unique()

# Initialize the figure structure
fig_dict = {
    "data": [],
    "layout": {
        "xaxis": {"range": [30, 85], "title": "Life Expectancy"},
        "yaxis": {"title": "GDP per Capita", "type": "log"},
        "hovermode": "closest",
        "updatemenus": [{
            "buttons": [
                {
                    "args": [None, {"frame": {"duration": 500, "redraw": False},
                                    "fromcurrent": True, "transition": {"duration": 300, "easing": "quadratic-in-out"}}],
                    "label": "Play",
                    "method": "animate"
                },
                {
                    "args": [[None], {"frame": {"duration": 0, "redraw": False},
                                      "mode": "immediate",
                                      "transition": {"duration": 0}}],
                    "label": "Pause",
                    "method": "animate"
                }
            ],
            "direction": "left",
            "pad": {"r": 10, "t": 87},
            "showactive": False,
            "type": "buttons",
            "x": 0.1,
            "xanchor": "right",
            "y": 0,
            "yanchor": "top"
        }]
    },
    "frames": []
}

# Slider configuration
sliders_dict = {
    "active": 0,
    "yanchor": "top",
    "xanchor": "left",
    "currentvalue": {
        "font": {"size": 20},
        "prefix": "Year:",
        "visible": True,
        "xanchor": "right"
    },
    "transition": {"duration": 300, "easing": "cubic-in-out"},
    "pad": {"b": 10, "t": 50},
    "len": 0.9,
    "x": 0.1,
    "y": 0,
    "steps": []
}

# Function to create the data for each continent and year
def create_data(year, continent):
    dataset_by_year = dataset[dataset["year"] == int(year)]
    dataset_by_year_and_cont = dataset_by_year[dataset_by_year["continent"] == continent]
    
    return {
        "x": list(dataset_by_year_and_cont["lifeExp"]),
        "y": list(dataset_by_year_and_cont["gdpPercap"]),
        "mode": "markers",
        "text": list(dataset_by_year_and_cont["country"]),
        "marker": {
            "sizemode": "area",
            "sizeref": 200000,
            "size": list(dataset_by_year_and_cont["pop"])
        },
        "name": continent
    }

# Add initial data for the first year
year = 1952
for continent in continents:
    fig_dict["data"].append(create_data(year, continent))

# Create frames for animation (for each year)
for year in years:
    frame = {"data": [], "name": str(year)}
    
    # Add data for each continent in the given year
    for continent in continents:
        frame["data"].append(create_data(year, continent))
    
    fig_dict["frames"].append(frame)
    
    # Create steps for the slider
    slider_step = {
        "args": [
            [year],
            {"frame": {"duration": 300, "redraw": False},
             "mode": "immediate",
             "transition": {"duration": 300}}
        ],
        "label": year,
        "method": "animate"
    }
    sliders_dict["steps"].append(slider_step)

# Add the slider to the layout
fig_dict["layout"]["sliders"] = [sliders_dict]

# Create and show the figure
fig = go.Figure(fig_dict)
fig.show(renderer="png")

# %% [markdown]
# [Chatbot log](https://chatgpt.com/share/66f60eb5-5ac0-8006-aa40-194ea12108ce)

# %% [markdown]
# ### 8. Provide a second version of the figure from the previous problem where you edit the fig = px.scatter() function from the Gapminder code so that x is "percent change", y is "rank", size is "percent", and color="sex", animation_frame is "year", and animation_group and hover_name are "name". Then use size_max=50, range_x=[-0.005,0.005]) and remove the log_x=True and range_y parameters

# %%
import pandas as pd
import plotly.express as px

# Load the baby names dataset
bn = pd.read_csv('https://raw.githubusercontent.com/hadley/data-baby-names/master/baby-names.csv')

# Make identical boy and girl names distinct
bn['name'] = bn['name'] + " " + bn['sex']

# Rank names by percent within each year (lower rank = more popular)
bn['rank'] = bn.groupby('year')['percent'].rank(ascending=False)

# Sort by name and year
bn = bn.sort_values(['name', 'year'])

# Calculate the percent change from the previous year
bn['percent change'] = bn['percent'].diff()

# Identify new names (first appearance or name change) to prevent calculation across name boundaries
new_name = [True] + list(bn.name[:-1].values != bn.name[1:].values)
bn.loc[new_name, 'percent change'] = bn.loc[new_name, 'percent']

# Sort the dataset by year
bn = bn.sort_values('year')

# Restrict to "common" names (percent > 0.001)
bn = bn[bn.percent > 0.001]

# Create the scatter plot with the given specifications
fig = px.scatter(
    bn,
    x="percent change",  # X-axis as percent change
    y="rank",            # Y-axis as rank (lower rank = more popular)
    animation_frame="year",  # Animate by year
    animation_group="name",  # Group by name
    size="percent",          # Bubble size as percent
    color="sex",             # Color by sex (gender)
    hover_name="name",       # Hover info as name
    size_max=50,             # Set maximum bubble size
    range_x=[-0.005, 0.005]  # Limit x-axis range
)

# Reverse y-axis to put rank 1 at the top
fig.update_yaxes(autorange='reversed')

# Show the figure as PNG for compatibility with GitHub and MarkUs
fig.show(renderer="png")

# %% [markdown]
# [chatbot log](https://chatgpt.com/share/66f60eb5-5ac0-8006-aa40-194ea12108ce)

# %% [markdown]
# ### 9. Have you reviewed the course wiki-textbook and interacted with a ChatBot (or, if that wasn't sufficient, real people in the course piazza discussion board or TA office hours) to help you understand all the material in the tutorial and lecture that you didn't quite follow when you first saw it?

# %% [markdown]
# - I am figuring it out as we go!
